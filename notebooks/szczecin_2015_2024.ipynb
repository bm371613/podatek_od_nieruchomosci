# %% [markdown]
# Analizujemy dane dotyczące podatku od nieruchomości w Szczecinie w latach 2015-2024 płaconego za powierzchnię mieszkalną.

# %%
from lib import szczecin_2015_2024

# %% [markdown]
# # Podział na osoby fizyczne i prawne

# %%
(
    szczecin_2015_2024.get_summary_df()
    .set_index(['taxpayer_type', 'year'])
    .style
    .format('{:,.0f}')
    .bar()
)
# Out:
# <style type="text/css">
# #T_4c0c0_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 57.4%, transparent 57.4%);
# }
# #T_4c0c0_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 57.7%, transparent 57.7%);
# }
# #T_4c0c0_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 57.6%, transparent 57.6%);
# }
# #T_4c0c0_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 61.7%, transparent 61.7%);
# }
# #T_4c0c0_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 61.9%, transparent 61.9%);
# }
# #T_4c0c0_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 62.0%, transparent 62.0%);
# }
# #T_4c0c0_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 66.9%, transparent 66.9%);
# }
# #T_4c0c0_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 67.1%, transparent 67.1%);
# }
# #T_4c0c0_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 67.6%, transparent 67.6%);
# }
# #T_4c0c0_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 74.8%, transparent 74.8%);
# }
# #T_4c0c0_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 74.5%, transparent 74.5%);
# }
# #T_4c0c0_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 75.1%, transparent 75.1%);
# }
# #T_4c0c0_row4_col0, #T_4c0c0_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 81.3%, transparent 81.3%);
# }
# #T_4c0c0_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 80.8%, transparent 80.8%);
# }
# #T_4c0c0_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 86.3%, transparent 86.3%);
# }
# #T_4c0c0_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 85.9%, transparent 85.9%);
# }
# #T_4c0c0_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 86.4%, transparent 86.4%);
# }
# #T_4c0c0_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 91.5%, transparent 91.5%);
# }
# #T_4c0c0_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 91.2%, transparent 91.2%);
# }
# #T_4c0c0_row6_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 91.7%, transparent 91.7%);
# }
# #T_4c0c0_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 95.5%, transparent 95.5%);
# }
# #T_4c0c0_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 95.1%, transparent 95.1%);
# }
# #T_4c0c0_row7_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 95.6%, transparent 95.6%);
# }
# #T_4c0c0_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 98.3%, transparent 98.3%);
# }
# #T_4c0c0_row8_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 98.2%, transparent 98.2%);
# }
# #T_4c0c0_row8_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 98.4%, transparent 98.4%);
# }
# #T_4c0c0_row9_col0, #T_4c0c0_row9_col1, #T_4c0c0_row9_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_4c0c0_row10_col0, #T_4c0c0_row11_col0, #T_4c0c0_row12_col0, #T_4c0c0_row13_col0, #T_4c0c0_row14_col0, #T_4c0c0_row15_col0, #T_4c0c0_row16_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.2%, transparent 0.2%);
# }
# #T_4c0c0_row10_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 48.0%, transparent 48.0%);
# }
# #T_4c0c0_row10_col2, #T_4c0c0_row11_col2, #T_4c0c0_row12_col2, #T_4c0c0_row13_col2, #T_4c0c0_row14_col2, #T_4c0c0_row15_col2, #T_4c0c0_row17_col0, #T_4c0c0_row18_col0, #T_4c0c0_row19_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.3%, transparent 0.3%);
# }
# #T_4c0c0_row11_col1, #T_4c0c0_row12_col1, #T_4c0c0_row17_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 49.6%, transparent 49.6%);
# }
# #T_4c0c0_row13_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 48.7%, transparent 48.7%);
# }
# #T_4c0c0_row14_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 47.0%, transparent 47.0%);
# }
# #T_4c0c0_row15_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 46.8%, transparent 46.8%);
# }
# #T_4c0c0_row16_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 49.0%, transparent 49.0%);
# }
# #T_4c0c0_row16_col2, #T_4c0c0_row17_col2, #T_4c0c0_row18_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.4%, transparent 0.4%);
# }
# #T_4c0c0_row18_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 48.6%, transparent 48.6%);
# }
# #T_4c0c0_row19_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 48.1%, transparent 48.1%);
# }
# #T_4c0c0_row19_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.5%, transparent 0.5%);
# }
# </style>
# <table id="T_4c0c0">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4c0c0_level0_col0" class="col_heading level0 col0" >n_taxpayers</th>
#       <th id="T_4c0c0_level0_col1" class="col_heading level0 col1" >total_area</th>
#       <th id="T_4c0c0_level0_col2" class="col_heading level0 col2" >n_accounts</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >taxpayer_type</th>
#       <th class="index_name level1" >year</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4c0c0_level0_row0" class="row_heading level0 row0" rowspan="10">Osoba fizyczna</th>
#       <th id="T_4c0c0_level1_row0" class="row_heading level1 row0" >2015</th>
#       <td id="T_4c0c0_row0_col0" class="data row0 col0" >97,380</td>
#       <td id="T_4c0c0_row0_col1" class="data row0 col1" >4,820,994</td>
#       <td id="T_4c0c0_row0_col2" class="data row0 col2" >63,617</td>
#     </tr>
#     <tr>
#       <th id="T_4c0c0_level1_row1" class="row_heading level1 row1" >2016</th>
#       <td id="T_4c0c0_row1_col0" class="data row1 col0" >104,576</td>
#       <td id="T_4c0c0_row1_col1" class="data row1 col1" >5,173,086</td>
#       <td id="T_4c0c0_row1_col2" class="data row1 col2" >68,580</td>
#     </tr>
#     <tr>
#       <th id="T_4c0c0_level1_row2" class="row_heading level1 row2" >2017</th>
#       <td id="T_4c0c0_row2_col0" class="data row2 col0" >113,404</td>
#       <td id="T_4c0c0_row2_col1" class="data row2 col1" >5,604,740</td>
#       <td id="T_4c0c0_row2_col2" class="data row2 col2" >74,677</td>
#     </tr>
#     <tr>
#       <th id="T_4c0c0_level1_row3" class="row_heading level1 row3" >2018</th>
#       <td id="T_4c0c0_row3_col0" class="data row3 col0" >126,901</td>
#       <td id="T_4c0c0_row3_col1" class="data row3 col1" >6,224,555</td>
#       <td id="T_4c0c0_row3_col2" class="data row3 col2" >83,033</td>
#     </tr>
#     <tr>
#       <th id="T_4c0c0_level1_row4" class="row_heading level1 row4" >2019</th>
#       <td id="T_4c0c0_row4_col0" class="data row4 col0" >137,870</td>
#       <td id="T_4c0c0_row4_col1" class="data row4 col1" >6,751,368</td>
#       <td id="T_4c0c0_row4_col2" class="data row4 col2" >89,877</td>
#     </tr>
#     <tr>
#       <th id="T_4c0c0_level1_row5" class="row_heading level1 row5" >2020</th>
#       <td id="T_4c0c0_row5_col0" class="data row5 col0" >146,468</td>
#       <td id="T_4c0c0_row5_col1" class="data row5 col1" >7,181,495</td>
#       <td id="T_4c0c0_row5_col2" class="data row5 col2" >95,533</td>
#     </tr>
#     <tr>
#       <th id="T_4c0c0_level1_row6" class="row_heading level1 row6" >2021</th>
#       <td id="T_4c0c0_row6_col0" class="data row6 col0" >155,279</td>
#       <td id="T_4c0c0_row6_col1" class="data row6 col1" >7,618,133</td>
#       <td id="T_4c0c0_row6_col2" class="data row6 col2" >101,345</td>
#     </tr>
#     <tr>
#       <th id="T_4c0c0_level1_row7" class="row_heading level1 row7" >2022</th>
#       <td id="T_4c0c0_row7_col0" class="data row7 col0" >161,934</td>
#       <td id="T_4c0c0_row7_col1" class="data row7 col1" >7,947,553</td>
#       <td id="T_4c0c0_row7_col2" class="data row7 col2" >105,640</td>
#     </tr>
#     <tr>

# %% [markdown]
# Płatnicy będący osobami prawnymi stanowią niewielką część płatników i kont.
# W przypadku osób prawnych liczba płatników i kont jest identyczna.
# Ta liczba rosła w danym okresie od 296 do 522, ale powierzchnia mieszkalna, za którą płaciły osoby prawne nie zmieniała się istotnie.
#
# Płatnicy będący osobami fizycznymi stanowią zdecydowaną większość płatników i kont - rozróżnienie staje się istotne zapewne ze względu na małżeństwa ze wspólnotą majątkową.
# Powierzchnia mieszkalna, za którą płaciły osoby fizyczne oraz liczba płatników rosły przez cały okres.
#
# Wzrost powierzchni wiąże się z budową mieszkań, a wzrost liczby płatników - ze wzrostem liczby osób posiadających mieszkanie.

# %% [markdown]
# # Dane szczegółowe dotyczące osób fizycznych
#
# Dane nt. osób fizycznych mamy też w rozbiciu na grupy podatników.
# Grupy definiowane są przez powierzchnię mieszkalną, od której podatnicy płacili podatek:
#
# - do 50m2
# - od 50m2 do 100m2
# - od 100m2 do 200m2
# - od 200m2 do 500m2
# - od 500m2 do 2000m2
# - powyżej 2000m2

# %%
detail_df = szczecin_2015_2024.get_details_df()
(
    detail_df
    .style
    .format('{:,.0f}', na_rep='', subset=['area_min', 'area_max', 'n_taxpayers', 'total_area', 'n_accounts'])
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_a1f40">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a1f40_level0_col0" class="col_heading level0 col0" >year</th>
#       <th id="T_a1f40_level0_col1" class="col_heading level0 col1" >area_min</th>
#       <th id="T_a1f40_level0_col2" class="col_heading level0 col2" >area_max</th>
#       <th id="T_a1f40_level0_col3" class="col_heading level0 col3" >n_taxpayers</th>
#       <th id="T_a1f40_level0_col4" class="col_heading level0 col4" >total_area</th>
#       <th id="T_a1f40_level0_col5" class="col_heading level0 col5" >n_accounts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a1f40_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a1f40_row0_col0" class="data row0 col0" >2015</td>
#       <td id="T_a1f40_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_a1f40_row0_col2" class="data row0 col2" >50</td>
#       <td id="T_a1f40_row0_col3" class="data row0 col3" >23,241</td>
#       <td id="T_a1f40_row0_col4" class="data row0 col4" >665,655</td>
#       <td id="T_a1f40_row0_col5" class="data row0 col5" >16,923</td>
#     </tr>
#     <tr>
#       <th id="T_a1f40_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a1f40_row1_col0" class="data row1 col0" >2015</td>
#       <td id="T_a1f40_row1_col1" class="data row1 col1" >50</td>
#       <td id="T_a1f40_row1_col2" class="data row1 col2" >100</td>
#       <td id="T_a1f40_row1_col3" class="data row1 col3" >51,729</td>
#       <td id="T_a1f40_row1_col4" class="data row1 col4" >2,254,612</td>
#       <td id="T_a1f40_row1_col5" class="data row1 col5" >33,535</td>
#     </tr>
#     <tr>
#       <th id="T_a1f40_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a1f40_row2_col0" class="data row2 col0" >2015</td>
#       <td id="T_a1f40_row2_col1" class="data row2 col1" >100</td>
#       <td id="T_a1f40_row2_col2" class="data row2 col2" >200</td>
#       <td id="T_a1f40_row2_col3" class="data row2 col3" >20,121</td>
#       <td id="T_a1f40_row2_col4" class="data row2 col4" >1,571,197</td>
#       <td id="T_a1f40_row2_col5" class="data row2 col5" >11,885</td>
#     </tr>
#     <tr>
#       <th id="T_a1f40_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a1f40_row3_col0" class="data row3 col0" >2015</td>
#       <td id="T_a1f40_row3_col1" class="data row3 col1" >200</td>
#       <td id="T_a1f40_row3_col2" class="data row3 col2" >500</td>
#       <td id="T_a1f40_row3_col3" class="data row3 col3" >2,250</td>
#       <td id="T_a1f40_row3_col4" class="data row3 col4" >310,652</td>
#       <td id="T_a1f40_row3_col5" class="data row3 col5" >1,251</td>
#     </tr>
#     <tr>
#       <th id="T_a1f40_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a1f40_row4_col0" class="data row4 col0" >2015</td>
#       <td id="T_a1f40_row4_col1" class="data row4 col1" >500</td>
#       <td id="T_a1f40_row4_col2" class="data row4 col2" >2,000</td>
#       <td id="T_a1f40_row4_col3" class="data row4 col3" >39</td>
#       <td id="T_a1f40_row4_col4" class="data row4 col4" >18,877</td>
#       <td id="T_a1f40_row4_col5" class="data row4 col5" >23</td>
#     </tr>
#     <tr>
#       <th id="T_a1f40_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a1f40_row5_col0" class="data row5 col0" >2016</td>
#       <td id="T_a1f40_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_a1f40_row5_col2" class="data row5 col2" >50</td>
#       <td id="T_a1f40_row5_col3" class="data row5 col3" >25,401</td>
#       <td id="T_a1f40_row5_col4" class="data row5 col4" >728,706</td>
#       <td id="T_a1f40_row5_col5" class="data row5 col5" >18,547</td>
#     </tr>
#     <tr>
#       <th id="T_a1f40_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a1f40_row6_col0" class="data row6 col0" >2016</td>
#       <td id="T_a1f40_row6_col1" class="data row6 col1" >50</td>
#       <td id="T_a1f40_row6_col2" class="data row6 col2" >100</td>
#       <td id="T_a1f40_row6_col3" class="data row6 col3" >55,435</td>
#       <td id="T_a1f40_row6_col4" class="data row6 col4" >2,427,131</td>
#       <td id="T_a1f40_row6_col5" class="data row6 col5" >36,078</td>
#     </tr>
#     <tr>
#       <th id="T_a1f40_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a1f40_row7_col0" class="data row7 col0" >2016</td>
#       <td id="T_a1f40_row7_col1" class="data row7 col1" >100</td>
#       <td id="T_a1f40_row7_col2" class="data row7 col2" >200</td>
#       <td id="T_a1f40_row7_col3" class="data row7 col3" >21,305</td>
#       <td id="T_a1f40_row7_col4" class="data row7 col4" >1,664,563</td>
#       <td id="T_a1f40_row7_col5" class="data row7 col5" >12,594</td>
#     </tr>
#     <tr>
#       <th id="T_a1f40_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a1f40_row8_col0" class="data row8 col0" >2016</td>
#       <td id="T_a1f40_row8_col1" class="data row8 col1" >200</td>
#       <td id="T_a1f40_row8_col2" class="data row8 col2" >500</td>
#       <td id="T_a1f40_row8_col3" class="data row8 col3" >2,397</td>
#       <td id="T_a1f40_row8_col4" class="data row8 col4" >332,442</td>
#       <td id="T_a1f40_row8_col5" class="data row8 col5" >1,338</td>
#     </tr>
#     <tr>
#       <th id="T_a1f40_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a1f40_row9_col0" class="data row9 col0" >2016</td>
#       <td id="T_a1f40_row9_col1" class="data row9 col1" >500</td>
#       <td id="T_a1f40_row9_col2" class="data row9 col2" >2,000</td>
#       <td id="T_a1f40_row9_col3" class="data row9 col3" >38</td>
#       <td id="T_a1f40_row9_col4" class="data row9 col4" >20,244</td>
#       <td id="T_a1f40_row9_col5" class="data row9 col5" >23</td>
#     </tr>
#     <tr>
#       <th id="T_a1f40_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a1f40_row10_col0" class="data row10 col0" >2017</td>
#       <td id="T_a1f40_row10_col1" class="data row10 col1" >0</td>
#       <td id="T_a1f40_row10_col2" class="data row10 col2" >50</td>
#       <td id="T_a1f40_row10_col3" class="data row10 col3" >28,071</td>
#       <td id="T_a1f40_row10_col4" class="data row10 col4" >807,413</td>
#       <td id="T_a1f40_row10_col5" class="data row10 col5" >20,534</td>
#     </tr>
#     <tr>
#       <th id="T_a1f40_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a1f40_row11_col0" class="data row11 col0" >2017</td>
#       <td id="T_a1f40_row11_col1" class="data row11 col1" >50</td>
#       <td id="T_a1f40_row11_col2" class="data row11 col2" >100</td>
#       <td id="T_a1f40_row11_col3" class="data row11 col3" >60,049</td>
#       <td id="T_a1f40_row11_col4" class="data row11 col4" >2,640,211</td>
#       <td id="T_a1f40_row11_col5" class="data row11 col5" >39,251</td>
#     </tr>
#     <tr>
#       <th id="T_a1f40_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_a1f40_row12_col0" class="data row12 col0" >2017</td>
#       <td id="T_a1f40_row12_col1" class="data row12 col1" >100</td>
#       <td id="T_a1f40_row12_col2" class="data row12 col2" >200</td>
#       <td id="T_a1f40_row12_col3" class="data row12 col3" >22,666</td>
#       <td id="T_a1f40_row12_col4" class="data row12 col4" >1,773,442</td>
#       <td id="T_a1f40_row12_col5" class="data row12 col5" >13,424</td>
#     </tr>
#     <tr>
#       <th id="T_a1f40_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_a1f40_row13_col0" class="data row13 col0" >2017</td>
#       <td id="T_a1f40_row13_col1" class="data row13 col1" >200</td>
#       <td id="T_a1f40_row13_col2" class="data row13 col2" >500</td>
#       <td id="T_a1f40_row13_col3" class="data row13 col3" >2,572</td>
#       <td id="T_a1f40_row13_col4" class="data row13 col4" >358,717</td>
#       <td id="T_a1f40_row13_col5" class="data row13 col5" >1,441</td>
#     </tr>
#     <tr>
#       <th id="T_a1f40_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_a1f40_row14_col0" class="data row14 col0" >2017</td>
#       <td id="T_a1f40_row14_col1" class="data row14 col1" >500</td>
#       <td id="T_a1f40_row14_col2" class="data row14 col2" >2,000</td>
#       <td

# %% [markdown]
# Najwyższa grupa (powyżej 2000m2) jest bardzo nieliczna - wygląda na to, że to jedno małżeństwo.
#
# Dla uproszczenia zredukujmy podział na dwie grupy, poniżej i powyżej 200m2,
# co można uznać za punkt odcięcia między wysokim komfortem mieszkalnym w mieście, a inwestycją w nieruchomości lub luksusem.

# %%
cutoff = 200

two_way_split_details_df = (
    detail_df
    .assign(group=lambda df: df.apply(lambda row: f'below {cutoff}' if row['area_max'] <= cutoff else f'above {cutoff}', axis=1))
    .groupby(['group', 'year'])
    [['n_taxpayers', 'n_accounts', 'total_area']]
    .sum()
)
(
    two_way_split_details_df
    .style
    .format('{:,.0f}')
    .bar()
)
# Out:
# <style type="text/css">
# #T_0cd99_row0_col0, #T_0cd99_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 1.4%, transparent 1.4%);
# }
# #T_0cd99_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 1.2%, transparent 1.2%);
# }
# #T_0cd99_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 4.3%, transparent 4.3%);
# }
# #T_0cd99_row1_col0, #T_0cd99_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 1.5%, transparent 1.5%);
# }
# #T_0cd99_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 1.3%, transparent 1.3%);
# }
# #T_0cd99_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 4.6%, transparent 4.6%);
# }
# #T_0cd99_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 1.6%, transparent 1.6%);
# }
# #T_0cd99_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 5.0%, transparent 5.0%);
# }
# #T_0cd99_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 1.8%, transparent 1.8%);
# }
# #T_0cd99_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 5.5%, transparent 5.5%);
# }
# #T_0cd99_row4_col0, #T_0cd99_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 2.0%, transparent 2.0%);
# }
# #T_0cd99_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 1.7%, transparent 1.7%);
# }
# #T_0cd99_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 6.2%, transparent 6.2%);
# }
# #T_0cd99_row5_col0, #T_0cd99_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 2.2%, transparent 2.2%);
# }
# #T_0cd99_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 1.9%, transparent 1.9%);
# }
# #T_0cd99_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 6.9%, transparent 6.9%);
# }
# #T_0cd99_row6_col0, #T_0cd99_row9_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 2.4%, transparent 2.4%);
# }
# #T_0cd99_row6_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 7.5%, transparent 7.5%);
# }
# #T_0cd99_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 2.5%, transparent 2.5%);
# }
# #T_0cd99_row7_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 8.0%, transparent 8.0%);
# }
# #T_0cd99_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 2.7%, transparent 2.7%);
# }
# #T_0cd99_row8_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 2.3%, transparent 2.3%);
# }
# #T_0cd99_row8_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 8.6%, transparent 8.6%);
# }
# #T_0cd99_row9_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 2.8%, transparent 2.8%);
# }
# #T_0cd99_row9_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 8.9%, transparent 8.9%);
# }
# #T_0cd99_row10_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 57.6%, transparent 57.6%);
# }
# #T_0cd99_row10_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 57.8%, transparent 57.8%);
# }
# #T_0cd99_row10_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 58.5%, transparent 58.5%);
# }
# #T_0cd99_row11_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 61.9%, transparent 61.9%);
# }
# #T_0cd99_row11_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 62.3%, transparent 62.3%);
# }
# #T_0cd99_row11_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 62.8%, transparent 62.8%);
# }
# #T_0cd99_row12_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 67.2%, transparent 67.2%);
# }
# #T_0cd99_row12_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 67.8%, transparent 67.8%);
# }
# #T_0cd99_row12_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 68.1%, transparent 68.1%);
# }
# #T_0cd99_row13_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 75.2%, transparent 75.2%);
# }
# #T_0cd99_row13_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 75.4%, transparent 75.4%);
# }
# #T_0cd99_row13_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 75.6%, transparent 75.6%);
# }
# #T_0cd99_row14_col0, #T_0cd99_row14_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 81.6%, transparent 81.6%);
# }
# #T_0cd99_row14_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 81.8%, transparent 81.8%);
# }
# #T_0cd99_row15_col0, #T_0cd99_row15_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 86.6%, transparent 86.6%);
# }
# #T_0cd99_row15_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 86.8%, transparent 86.8%);
# }
# #T_0cd99_row16_col0, #T_0cd99_row16_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 91.8%, transparent 91.8%);
# }
# #T_0cd99_row16_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 91.9%, transparent 91.9%);
# }
# #T_0cd99_row17_col0, #T_0cd99_row17_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 95.6%, transparent 95.6%);
# }
# #T_0cd99_row17_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 95.7%, transparent 95.7%);
# }
# #T_0cd99_row18_col0, #T_0cd99_row18_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 98.4%, transparent 98.4%);
# }
# #T_0cd99_row18_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 98.5%, transparent 98.5%);
# }
# #T_0cd99_row19_col0, #T_0cd99_row19_col1, #T_0cd99_row19_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_0cd99">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0cd99_level0_col0" class="col_heading level0 col0" >n_taxpayers</th>
#       <th id="T_0cd99_level0_col1" class="col_heading level0 col1" >n_accounts</th>
#       <th id="T_0cd99_level0_col2" class="col_heading level0 col2" >total_area</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >group</th>
#       <th class="index_name level1" >year</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0cd99_level0_row0" class="row_heading level0 row0" rowspan="10">above 200</th>
#       <th id="T_0cd99_level1_row0" class="row_heading level1 row0" >2015</th>
#       <td id="T_0cd99_row0_col0" class="data row0 col0" >2,289</td>
#       <td id="T_0cd99_row0_col1" class="data row0 col1" >1,274</td>
#       <td id="T_0cd99_row0_col2" class="data row0 col2" >329,530</td>
#     </tr>
#     <tr>
#       <th id="T_0cd99_level1_row1" class="row_heading level1 row1" >2016</th>
#       <td id="T_0cd99_row1_col0" class="data row1 col0" >2,435</td>
#       <td id="T_0cd99_row1_col1" class="data row1 col1" >1,361</td>
#       <td id="T_0cd99_row1_col2" class="data row1 col2" >352,686</td>
#     </tr>
#     <tr>
#       <th id="T_0cd99_level1_row2" class="row_heading level1 row2" >2017</th>
#       <td id="T_0cd99_row2_col0" class="data row2 col0" >2,618</td>
#       <td id="T_0cd99_row2_col1" class="data row2 col1" >1,468</td>
#       <td id="T_0cd99_row2_col2" class="data row2 col2" >383,675</td>
#     </tr>
#     <tr>
#       <th id="T_0cd99_level1_row3" class="row_heading level1 row3" >2018</th>
#       <td id="T_0cd99_row3_col0" class="data row3 col0" >2,903</td>
#       <td id="T_0cd99_row3_col1" class="data row3 col1" >1,619</td>
#       <td id="T_0cd99_row3_col2" class="data row3 col2" >420,790</td>
#     </tr>
#     <tr>
#       <th id="T_0cd99_level1_row4" class="row_heading level1 row4" >2019</th>
#       <td id="T_0cd99_row4_col0" class="data row4 col0" >3,285</td>
#       <td id="T_0cd99_row4_col1" class="data row4 col1" >1,827</td>
#       <td id="T_0cd99_row4_col2" class="data row4 col2" >476,030</td>
#     </tr>
#     <tr>
#       <th id="T_0cd99_level1_row5" class="row_heading level1 row5" >2020</th>
#       <td id="T_0cd99_row5_col0" class="data row5 col0" >3,594</td>
#       <td id="T_0cd99_row5_col1" class="data row5 col1"

# %% [markdown]
# Mając uproszczony podział na te dwie grupy, sprawdźmy jak przyrastała powierzchnia mieszkalna rok do roku.
#
# Dla każdego roku zobaczymy jak wzrost powierzchni lokali mieszkalnej był rozłożony między grupy.

# %%
(
    two_way_split_details_df
    .reset_index()
    .pivot(index='year', columns='group', values='total_area')
    .diff(1).dropna()
    .apply(lambda row: row / row.sum(), axis=1)
    .style
    .format('{:.2%}')
    .bar()
)
# Out:
# <style type="text/css">
# #T_2f70d_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 37.4%, transparent 37.4%);
# }
# #T_2f70d_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 99.4%, transparent 99.4%);
# }
# #T_2f70d_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 40.8%, transparent 40.8%);
# }
# #T_2f70d_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 98.7%, transparent 98.7%);
# }
# #T_2f70d_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 34.0%, transparent 34.0%);
# }
# #T_2f70d_row2_col1, #T_2f70d_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_2f70d_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 59.6%, transparent 59.6%);
# }
# #T_2f70d_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 95.2%, transparent 95.2%);
# }
# #T_2f70d_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 65.9%, transparent 65.9%);
# }
# #T_2f70d_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 94.0%, transparent 94.0%);
# }
# #T_2f70d_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 60.7%, transparent 60.7%);
# }
# #T_2f70d_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 95.0%, transparent 95.0%);
# }
# #T_2f70d_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 71.9%, transparent 71.9%);
# }
# #T_2f70d_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 92.9%, transparent 92.9%);
# }
# #T_2f70d_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 98.6%, transparent 98.6%);
# }
# #T_2f70d_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 87.9%, transparent 87.9%);
# }
# #T_2f70d_row8_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 87.7%, transparent 87.7%);
# }
# </style>
# <table id="T_2f70d">
#   <thead>
#     <tr>
#       <th class="index_name level0" >group</th>
#       <th id="T_2f70d_level0_col0" class="col_heading level0 col0" >above 200</th>
#       <th id="T_2f70d_level0_col1" class="col_heading level0 col1" >below 200</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >year</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2f70d_level0_row0" class="row_heading level0 row0" >2016</th>
#       <td id="T_2f70d_row0_col0" class="data row0 col0" >6.58%</td>
#       <td id="T_2f70d_row0_col1" class="data row0 col1" >93.42%</td>
#     </tr>
#     <tr>
#       <th id="T_2f70d_level0_row1" class="row_heading level0 row1" >2017</th>
#       <td id="T_2f70d_row1_col0" class="data row1 col0" >7.18%</td>
#       <td id="T_2f70d_row1_col1" class="data row1 col1" >92.82%</td>
#     </tr>
#     <tr>
#       <th id="T_2f70d_level0_row2" class="row_heading level0 row2" >2018</th>
#       <td id="T_2f70d_row2_col0" class="data row2 col0" >5.99%</td>
#       <td id="T_2f70d_row2_col1" class="data row2 col1" >94.01%</td>
#     </tr>
#     <tr>
#       <th id="T_2f70d_level0_row3" class="row_heading level0 row3" >2019</th>
#       <td id="T_2f70d_row3_col0" class="data row3 col0" >10.49%</td>
#       <td id="T_2f70d_row3_col1" class="data row3 col1" >89.51%</td>
#     </tr>
#     <tr>
#       <th id="T_2f70d_level0_row4" class="row_heading level0 row4" >2020</th>
#       <td id="T_2f70d_row4_col0" class="data row4 col0" >11.59%</td>
#       <td id="T_2f70d_row4_col1" class="data row4 col1" >88.41%</td>
#     </tr>
#     <tr>
#       <th id="T_2f70d_level0_row5" class="row_heading level0 row5" >2021</th>
#       <td id="T_2f70d_row5_col0" class="data row5 col0" >10.67%</td>
#       <td id="T_2f70d_row5_col1" class="data row5 col1" >89.33%</td>
#     </tr>
#     <tr>
#       <th id="T_2f70d_level0_row6" class="row_heading level0 row6" >2022</th>
#       <td id="T_2f70d_row6_col0" class="data row6 col0" >12.64%</td>
#       <td id="T_2f70d_row6_col1" class="data row6 col1" >87.36%</td>
#     </tr>
#     <tr>
#       <th id="T_2f70d_level0_row7" class="row_heading level0 row7" >2023</th>
#       <td id="T_2f70d_row7_col0" class="data row7 col0" >17.33%</td>
#       <td id="T_2f70d_row7_col1" class="data row7 col1" >82.67%</td>
#     </tr>
#     <tr>
#       <th id="T_2f70d_level0_row8" class="row_heading level0 row8" >2024</th>
#       <td id="T_2f70d_row8_col0" class="data row8 col0" >17.59%</td>
#       <td id="T_2f70d_row8_col1" class="data row8 col1" >82.41%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# - W latach 2015-2018 grupie "powyżej 200m2" przypadało 6-7% przyrostu powierzchni mieszkalnej
# - W latach 2019-2022 było to już 10-12%
# - Od roku 2023 jest to 17%
